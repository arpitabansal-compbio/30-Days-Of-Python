# %% [markdown]
# <a href="https://colab.research.google.com/github/arpitabansal-compbio/30-Days-Of-Python/blob/main/Day_02_Variables_And_Input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
user_name = input("What is your name? ")
print("Welcome to your coding journey,")
print(user_name)
# Out:
# What is your name? ARPITA BANSAL
# Welcome to your coding journey,
# ARPITA BANSAL

# %%
name = input("what is your name? ")
print("hello, " + name)
adenine_count = int(input("Number of Adenine bases you counted in the DNA SEQUENCE? "))
total_weight = adenine_count * 331
print(f"Hello {name}! Your {adenine_count} Adenine bases contribute {total_weight} atomic mass units to your DNA sequence.")
# Out:
# what is your name? ARPITA BANSAL
# hello, ARPITA BANSAL
# Number of Adenine bases you counted in the DNA SEQUENCE? 30
# Hello ARPITA BANSAL! Your 30 Adenine bases contribute 9930 atomic mass units to your DNA sequence.
